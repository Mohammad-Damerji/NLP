# %%
import nltk
from nltk.corpus import brown
nltk.download('brown')

import numpy as np

#from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Embedding
from keras.layers import LSTM
from keras.models import Model
from keras.layers import Input

from keras.losses import CosineSimilarity

from annoy import AnnoyIndex
import random
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!

# %%
corpus = brown.sents()

# %%
max_sequence_length = 32

# %% [markdown]
# ## The function "createDic:"
# * Input: list of lists (sentences).
# * Output: dictionary contians the words where each word has an index.

# %%
def createDic(listOflists):
    i=1
    dic={}
    for lst in listOflists:
        for word in lst:
            if word.lower() not in dic:
                dic[word.lower()] = i
                i+=1
    return dic

# %%
myDic = createDic(corpus)
myDic
# Out:
# {'the': 1,
#  'fulton': 2,
#  'county': 3,
#  'grand': 4,
#  'jury': 5,
#  'said': 6,
#  'friday': 7,
#  'an': 8,
#  'investigation': 9,
#  'of': 10,
#  "atlanta's": 11,
#  'recent': 12,
#  'primary': 13,
#  'election': 14,
#  'produced': 15,
#  '``': 16,
#  'no': 17,
#  'evidence': 18,
#  "''": 19,
#  'that': 20,
#  'any': 21,
#  'irregularities': 22,
#  'took': 23,
#  'place': 24,
#  '.': 25,
#  'further': 26,
#  'in': 27,
#  'term-end': 28,
#  'presentments': 29,
#  'city': 30,
#  'executive': 31,
#  'committee': 32,
#  ',': 33,
#  'which': 34,
#  'had': 35,
#  'over-all': 36,
#  'charge': 37,
#  'deserves': 38,
#  'praise': 39,
#  'and': 40,
#  'thanks': 41,
#  'atlanta': 42,
#  'for': 43,
#  'manner': 44,
#  'was': 45,
#  'conducted': 46,
#  'september-october': 47,
#  'term': 48,
#  'been': 49,
#  'charged': 50,
#  'by': 51,
#  'superior': 52,
#  'court': 53,
#  'judge': 54,
#  'durwood': 55,
#  'pye': 56,
#  'to': 57,
#  'investigate': 58,
#  'reports': 59,
#  'possible': 60,
#  'hard-fought': 61,
#  'won': 62,
#  'mayor-nominate': 63,
#  'ivan': 64,
#  'allen': 65,
#  'jr.': 66,
#  'only': 67,
#  'a': 68,
#  'relative': 69,
#  'handful': 70,
#  'such': 71,
#  'received': 72,
#  'considering': 73,
#  'widespread': 74,
#  'interest': 75,
#  'number': 76,
#  'voters': 77,
#  'size': 78,
#  'this': 79,
#  'it': 80,
#  'did': 81,
#  'find': 82,
#  'many': 83,
#  "georgia's": 84,
#  'registration': 85,
#  'laws': 86,
#  'are': 87,
#  'outmoded': 88,
#  'or': 89,
#  'inadequate': 90,
#  'often': 91,
#  'ambiguous': 92,
#  'recommended': 93,
#  'legislators': 94,
#  'act': 95,
#  'have': 96,
#  'these': 97,
#  'studied': 98,
#  'revised': 99,
#  'end': 100,
#  'modernizing': 101,
#  'improving': 102,
#  'them': 103,
#  'commented': 104,
#  'on': 105,
#  'other': 106,
#  'topics': 107,
#  'among': 108,
#  'purchasing': 109,
#  'departments': 110,
#  'well': 111,
#  'operated': 112,
#  'follow': 113,
#  'generally': 114,
#  'accepted': 115,
#  'practices': 116,
#  'inure': 117,
#  'best': 118,
#  'both': 119,
#  'governments': 120,
#  'merger': 121,
#  'proposed': 122,
#  'however': 123,
#  'believes': 124,
#  'two': 125,
#  'offices': 126,
#  'should': 127,
#  'be': 128,
#  'combined': 129,
#  'achieve': 130,
#  'greater': 131,
#  'efficiency': 132,
#  'reduce': 133,
#  'cost': 134,
#  'administration': 135,
#  'department': 136,
#  'is': 137,
#  'lacking': 138,
#  'experienced': 139,
#  'clerical': 140,
#  'personnel': 141,
#  'as': 142,
#  'result': 143,
#  'policies': 144,
#  'urged': 145,
#  'take': 146,
#  'steps': 147,
#  'remedy': 148,
#  'problem': 149,
#  'implementation': 150,
#  'automobile': 151,
#  'title': 152,
#  'law': 153,
#  'also': 154,
#  'outgoing': 155,
#  'next': 156,
#  'legislature': 157,
#  'provide': 158,
#  'enabling': 159,
#  'funds': 160,
#  're-set': 161,
#  'effective': 162,
#  'date': 163,
#  'so': 164,
#  'orderly': 165,
#  'may': 166,
#  'effected': 167,
#  'swipe': 168,
#  'at': 169,
#  'state': 170,
#  'welfare': 171,
#  "department's": 172,
#  'handling': 173,
#  'federal': 174,
#  'granted': 175,
#  'child': 176,
#  'services': 177,
#  'foster': 178,
#  'homes': 179,
#  'one': 180,
#  'major': 181,
#  'items': 182,
#  'general': 183,
#  'assistance': 184,
#  'program': 185,
#  'but': 186,
#  'has': 187,
#  'seen': 188,
#  'fit': 189,
#  'distribute': 190,
#  'through': 191,
#  'all': 192,
#  'counties': 193,
#  'with': 194,
#  'exception': 195,
#  'receives': 196,
#  'none': 197,
#  'money': 198,
#  'jurors': 199,
#  'they': 200,
#  'realize': 201,
#  'proportionate': 202,
#  'distribution': 203,
#  'might': 204,
#  'disable': 205,
#  'our': 206,
#  'less': 207,
#  'populous': 208,
#  'nevertheless': 209,
#  'we': 210,
#  'feel': 211,
#  'future': 212,
#  'receive': 213,
#  'some': 214,
#  'portion': 215,
#  'available': 216,
#  'failure': 217,
#  'do': 218,
#  'will': 219,
#  'continue': 220,
#  'disproportionate': 221,
#  'burden': 222,
#  'taxpayers': 223,
#  "ordinary's": 224,
#  'under': 225,
#  'fire': 226,
#  'its': 227,
#  'appointment': 228,
#  'appraisers': 229,
#  'guardians': 230,
#  'administrators': 231,
#  'awarding': 232,
#  'fees': 233,
#  'compensation': 234,
#  'wards': 235,
#  'protected': 236,
#  'found': 237,
#  'incorporated': 238,
#  'into': 239,
#  'operating': 240,
#  'procedures': 241,
#  'recommendations': 242,
#  'previous': 243,
#  'juries': 244,
#  'bar': 245,
#  'association': 246,
#  'interim': 247,
#  'citizens': 248,
#  'actions': 249,
#  'serve': 250,
#  'protect': 251,
#  'fact': 252,
#  'effect': 253,
#  "court's": 254,
#  'from': 255,
#  'undue': 256,
#  'costs': 257,
#  'appointed': 258,
#  'elected': 259,
#  'servants': 260,
#  'unmeritorious': 261,
#  'criticisms': 262,
#  'regarding': 263,
#  'new': 264,
#  'multi-million-dollar': 265,
#  'airport': 266,
#  'when': 267,
#  'management': 268,
#  'takes': 269,
#  'jan.': 270,
#  '1': 271,
#  'eliminate': 272,
#  'political': 273,
#  'influences': 274,
#  'not': 275,
#  'elaborate': 276,
#  'added': 277,
#  'there': 278,
#  'periodic': 279,
#  'surveillance': 280,
#  'pricing': 281,
#  'concessionaires': 282,
#  'purpose': 283,
#  'keeping': 284,
#  'prices': 285,
#  'reasonable': 286,
#  'ask': 287,
#  'jail': 288,
#  'deputies': 289,
#  'matters': 290,
#  ':': 291,
#  '(': 292,
#  ')': 293,
#  'four': 294,
#  'additional': 295,
#  'employed': 296,
#  'doctor': 297,
#  'medical': 298,
#  'intern': 299,
#  'extern': 300,
#  'night': 301,
#  'weekend': 302,
#  'duty': 303,
#  '2': 304,
#  'work': 305,
#  'officials': 306,
#  'pass': 307,
#  'legislation': 308,
#  'permit': 309,
#  'establishment': 310,
#  'fair': 311,
#  'equitable': 312,
#  'pension': 313,
#  'plan': 314,
#  'employes': 315,
#  'praised': 316,
#  'operation': 317,
#  'police': 318,
#  'tax': 319,
#  "commissioner's": 320,
#  'office': 321,
#  'bellwood': 322,
#  'alpharetta': 323,
#  'prison': 324,
#  'farms': 325,
#  'grady': 326,
#  'hospital': 327,
#  'health': 328,
#  'mayor': 329,
#  'william': 330,
#  'b.': 331,
#  'hartsfield': 332,
#  'filed': 333,
#  'suit': 334,
#  'divorce': 335,
#  'his': 336,
#  'wife': 337,
#  'pearl': 338,
#  'williams': 339,
#  'petition': 340,
#  'mental': 341,
#  'cruelty': 342,
#  'couple': 343,
#  'married': 344,
#  'aug.': 345,
#  '1913': 346,
#  'son': 347,
#  'berry': 348,
#  'daughter': 349,
#  'mrs.': 350,
#  'j.': 351,
#  'm.': 352,
#  'cheshire': 353,
#  'griffin': 354,
#  'attorneys': 355,
#  'amicable': 356,
#  'property': 357,
#  'settlement': 358,
#  'agreed': 359,
#  'upon': 360,
#  'listed': 361,
#  "mayor's": 362,
#  'occupation': 363,
#  'attorney': 364,
#  'age': 365,
#  '71': 366,
#  "wife's": 367,
#  '74': 368,
#  'birth': 369,
#  'opelika': 370,
#  'ala.': 371,
#  'lived': 372,
#  'together': 373,
#  'man': 374,
#  'more': 375,
#  'than': 376,
#  'year': 377,
#  'home': 378,
#  '637': 379,
#  'e.': 380,
#  'pelham': 381,
#  'rd.': 382,
#  'aj': 383,
#  'henry': 384,
#  'l.': 385,
#  'bowden': 386,
#  'brief': 387,
#  'interlude': 388,
#  'since': 389,
#  '1937': 390,
#  'career': 391,
#  'goes': 392,
#  'back': 393,
#  'council': 394,
#  '1923': 395,
#  'present': 396,
#  'expires': 397,
#  'he': 398,
#  'succeeded': 399,
#  'who': 400,
#  'became': 401,
#  'candidate': 402,
#  'sept.': 403,
#  '13': 404,
#  'after': 405,
#  'announced': 406,
#  'would': 407,
#  'run': 408,
#  'reelection': 409,
#  'georgia': 410,
#  'republicans': 411,
#  'getting': 412,
#  'strong': 413,
#  'encouragement': 414,
#  'enter': 415,
#  '1962': 416,
#  "governor's": 417,
#  'race': 418,
#  'top': 419,
#  'official': 420,
#  'wednesday': 421,
#  'robert': 422,
#  'snodgrass': 423,
#  'gop': 424,
#  'chairman': 425,
#  'meeting': 426,
#  'held': 427,
#  'tuesday': 428,
#  'blue': 429,
#  'ridge': 430,
#  'brought': 431,
#  'enthusiastic': 432,
#  'responses': 433,
#  'audience': 434,
#  'party': 435,
#  'james': 436,
#  'w.': 437,
#  'dorsey': 438,
#  'enthusiasm': 439,
#  'picking': 440,
#  'up': 441,
#  'rally': 442,
#  '8': 443,
#  'savannah': 444,
#  'newly': 445,
#  'texas': 446,
#  'sen.': 447,
#  'john': 448,
#  'tower': 449,
#  'featured': 450,
#  'speaker': 451,
#  'warned': 452,
#  'entering': 453,
#  'governor': 454,
#  'force': 455,
#  'petitions': 456,
#  'out': 457,
#  'voting': 458,
#  'precincts': 459,
#  'obtain': 460,
#  'signatures': 461,
#  'registered': 462,
#  'despite': 463,
#  'warning': 464,
#  'unanimous': 465,
#  'vote': 466,
#  'according': 467,
#  'attended': 468,
#  'crowd': 469,
#  'asked': 470,
#  'whether': 471,
#  'wanted': 472,
#  'wait': 473,
#  'make': 474,
#  'voted': 475,
#  '--': 476,
#  'were': 477,
#  'dissents': 478,
#  'largest': 479,
#  'hurdle': 480,
#  'face': 481,
#  'says': 482,
#  'before': 483,
#  'making': 484,
#  'first': 485,
#  'alternative': 486,
#  'courses': 487,
#  'must': 488,
#  'taken': 489,
#  'five': 490,
#  'per': 491,
#  'cent': 492,
#  'each': 493,
#  'sign': 494,
#  'requesting': 495,
#  'allowed': 496,
#  'names': 497,
#  'candidates': 498,
#  'ballot': 499,
#  'hold': 500,
#  'unit': 501,
#  'system': 502,
#  'opposes': 503,
#  'platform': 504,
#  'sam': 505,
#  'caldwell': 506,
#  'highway': 507,
#  'public': 508,
#  'relations': 509,
#  'director': 510,
#  'resigned': 511,
#  'lt.': 512,
#  'gov.': 513,
#  'garland': 514,
#  "byrd's": 515,
#  'campaign': 516,
#  "caldwell's": 517,
#  'resignation': 518,
#  'expected': 519,
#  'time': 520,
#  'rob': 521,
#  'ledford': 522,
#  'gainesville': 523,
#  'assistant': 524,
#  'three': 525,
#  'years': 526,
#  'gubernatorial': 527,
#  'starts': 528,
#  'become': 529,
#  'coordinator': 530,
#  'byrd': 531,
#  'wind': 532,
#  '1961': 533,
#  'session': 534,
#  'monday': 535,
#  'head': 536,
#  'where': 537,
#  'bond': 538,
#  'approved': 539,
#  'shortly': 540,
#  'adjournment': 541,
#  'afternoon': 542,
#  'senate': 543,
#  'approve': 544,
#  'study': 545,
#  'allotted': 546,
#  'rural': 547,
#  'urban': 548,
#  'areas': 549,
#  'determine': 550,
#  'what': 551,
#  'adjustments': 552,
#  'made': 553,
#  'vandiver': 554,
#  'traditional': 555,
#  'visit': 556,
#  'chambers': 557,
#  'toward': 558,
#  'likely': 559,
#  'mention': 560,
#  '$100': 561,
#  'million': 562,
#  'issue': 563,
#  'earlier': 564,
#  'priority': 565,
#  'item': 566,
#  'construction': 567,
#  'bonds': 568,
#  'meanwhile': 569,
#  'learned': 570,
#  'very': 571,
#  'near': 572,
#  'being': 573,
#  'ready': 574,
#  '$30': 575,
#  'worth': 576,
#  'reconstruction': 577,
#  'go': 578,
#  'courts': 579,
#  'friendly': 580,
#  'test': 581,
#  'validity': 582,
#  'then': 583,
#  'sales': 584,
#  'begin': 585,
#  'contracts': 586,
#  'let': 587,
#  'repair': 588,
#  'most': 589,
#  'heavily': 590,
#  'traveled': 591,
#  'highways': 592,
#  'source': 593,
#  '$3': 594,
#  '$4': 595,
#  'roads': 596,
#  'authority': 597,
#  'road': 598,
#  'revolving': 599,
#  'fund': 600,
#  'apparently': 601,
#  'intends': 602,
#  'issued': 603,
#  'every': 604,
#  'old': 605,
#  'ones': 606,
#  'paid': 607,
#  'off': 608,
#  'authorities': 609,
#  'opened': 610,
#  '1958': 611,
#  'battle': 612,
#  'against': 613,
#  'issuance': 614,
#  '$50': 615,
#  'marvin': 616,
#  'told': 617,
#  'constitution': 618,
#  'consulted': 619,
#  'yet': 620,
#  'about': 621,
#  'plans': 622,
#  'schley': 623,
#  'rep.': 624,
#  'd.': 625,
#  'offer': 626,
#  'resolution': 627,
#  'house': 628,
#  'rescind': 629,
#  "body's": 630,
#  'action': 631,
#  'itself': 632,
#  '$10': 633,
#  'day': 634,
#  'increase': 635,
#  'expense': 636,
#  'allowances': 637,
#  'sunday': 638,
#  'research': 639,
#  'done': 640,
#  'quickie': 641,
#  'can': 642,
#  'repealed': 643,
#  'outright': 644,
#  'notice': 645,
#  'given': 646,
#  'reconsideration': 647,
#  'sought': 648,
#  'while': 649,
#  'emphasizing': 650,
#  'technical': 651,
#  'details': 652,
#  'fully': 653,
#  'worked': 654,
#  'seek': 655,
#  'set': 656,
#  'aside': 657,
#  'privilege': 658,
#  '87-31': 659,
#  'similar': 660,
#  'passed': 661,
#  '29-5': 662,
#  'word': 663,
#  'offered': 664,
#  'pointed': 665,
#  'last': 666,
#  'november': 667,
#  'rejected': 668,
#  'constitutional': 669,
#  'amendment': 670,
#  'allow': 671,
#  'pay': 672,
#  'raises': 673,
#  'sessions': 674,
#  'veteran': 675,
#  'jackson': 676,
#  'legislator': 677,
#  'aid': 678,
#  'education': 679,
#  'something': 680,
#  'consistently': 681,
#  'opposed': 682,
#  'past': 683,
#  'mac': 684,
#  'barber': 685,
#  'commerce': 686,
#  'asking': 687,
#  'endorse': 688,
#  'increased': 689,
#  'support': 690,
#  'provided': 691,
#  'expended': 692,
#  '13th': 693,
#  'members': 694,
#  'congressional': 695,
#  'delegation': 696,
#  'washington': 697,
#  'like': 698,
#  'see': 699,
#  'congressmen': 700,
#  'specifically': 701,
#  'him': 702,
#  'tossed': 703,
#  'hopper': 704,
#  'formally': 705,
#  'read': 706,
#  'event': 707,
#  'congress': 708,
#  'does': 709,
#  'board': 710,
#  'directed': 711,
#  'give': 712,
#  'teacher': 713,
#  'colquitt': 714,
#  'long': 715,
#  'hot': 716,
#  'controversy': 717,
#  'miller': 718,
#  'school': 719,
#  'superintendent': 720,
#  'policeman': 721,
#  'put': 722,
#  'coolest': 723,
#  'i': 724,
#  'ever': 725,
#  'saw': 726,
#  'harry': 727,
#  'davis': 728,
#  'agriculture': 729,
#  'defeated': 730,
#  'felix': 731,
#  'bush': 732,
#  'principal': 733,
#  'democratic': 734,
#  '1,119': 735,
#  'votes': 736,
#  "saturday's": 737,
#  'got': 738,
#  '402': 739,
#  'ordinary': 740,
#  'carey': 741,
#  'armed': 742,
#  'pistol': 743,
#  'stood': 744,
#  'polls': 745,
#  'insure': 746,
#  'order': 747,
#  'calmest': 748,
#  'tom': 749,
#  'just': 750,
#  'church': 751,
#  "didn't": 752,
#  'smell': 753,
#  'drop': 754,
#  'liquor': 755,
#  'bit': 756,
#  'trouble': 757,
#  'leading': 758,
#  'quiet': 759,
#  'marked': 760,
#  'anonymous': 761,
#  'midnight': 762,
#  'phone': 763,
#  'calls': 764,
#  'veiled': 765,
#  'threats': 766,
#  'violence': 767,
#  'former': 768,
#  'george': 769,
#  'p.': 770,
#  'callan': 771,
#  'shot': 772,
#  'himself': 773,
#  'death': 774,
#  'march': 775,
#  '18': 776,
#  'days': 777,
#  'post': 778,
#  'dispute': 779,
#  'during': 780,
#  'reportedly': 781,
#  'telephone': 782,
#  'too': 783,
#  'subjected': 784,
#  'soon': 785,
#  'scheduled': 786,
#  'local': 787,
#  'feared': 788,
#  'carry': 789,
#  'gun': 790,
#  'promised': 791,
#  'sheriff': 792,
#  'tabb': 793,
#  'good': 794,
#  'promise': 795,
#  'everything': 796,
#  'went': 797,
#  'real': 798,
#  'smooth': 799,
#  "wasn't": 800,
#  'austin': 801,
#  'approval': 802,
#  'price': 803,
#  "daniel's": 804,
#  'abandoned': 805,
#  'seemed': 806,
#  'certain': 807,
#  'thursday': 808,
#  'adamant': 809,
#  'protests': 810,
#  'bankers': 811,
#  'daniel': 812,
#  'personally': 813,
#  'led': 814,
#  'fight': 815,
#  'measure': 816,
#  'watered': 817,
#  'down': 818,
#  'considerably': 819,
#  'rejection': 820,
#  'legislatures': 821,
#  'hearing': 822,
#  'revenue': 823,
#  'taxation': 824,
#  'rules': 825,
#  'automatically': 826,
#  'subcommittee': 827,
#  'week': 828,
#  'questions': 829,
#  'taunted': 830,
#  'appearing': 831,
#  'witnesses': 832,
#  'left': 833,
#  'little': 834,
#  'doubt': 835,
#  'recommend': 836,
#  'passage': 837,
#  'termed': 838,
#  'extremely': 839,
#  'conservative': 840,
#  'estimate': 841,
#  'produce': 842,
#  '17': 843,
#  'dollars': 844,
#  'help': 845,
#  'erase': 846,
#  'anticipated': 847,
#  'deficit': 848,
#  '63': 849,
#  'current': 850,
#  'fiscal': 851,
#  '31': 852,
#  'merely': 853,
#  'means': 854,
#  'enforcing': 855,
#  'escheat': 856,
#  'books': 857,
#  'republic': 858,
#  'permits': 859,
#  'over': 860,
#  'bank': 861,
#  'accounts': 862,
#  'stocks': 863,
#  'personal': 864,
#  'persons': 865,
#  'missing': 866,
#  'seven': 867,
#  'bill': 868,
#  'drafted': 869,
#  'banks': 870,
#  'insurance': 871,
#  'firms': 872,
#  'pipeline': 873,
#  'companies': 874,
#  'corporations': 875,
#  'report': 876,
#  'treasurer': 877,
#  'cannot': 878,
#  'enforced': 879,
#  'now': 880,
#  'because': 881,
#  'almost': 882,
#  'impossible': 883,
#  'locate': 884,
#  'declared': 885,
#  'dewey': 886,
#  'lawrence': 887,
#  'tyler': 888,
#  'lawyer': 889,
#  'representing': 890,
#  'sounded': 891,
#  'opposition': 892,
#  'keynote': 893,
#  'violate': 894,
#  'their': 895,
#  'contractual': 896,
#  'obligations': 897,
#  'depositors': 898,
#  'undermine': 899,
#  'confidence': 900,
#  'customers': 901,
#  'if': 902,
#  'you': 903,
#  'destroy': 904,
#  'economy': 905,
#  'circulation': 906,
#  'millions': 907,
#  'charles': 908,
#  'hughes': 909,
#  'sherman': 910,
#  'sponsor': 911,
#  'enact': 912,
#  'amount': 913,
#  'gift': 914,
#  "taxpayers'": 915,
#  'pockets': 916,
#  'contention': 917,
#  'denied': 918,
#  'several': 919,
#  'including': 920,
#  'scott': 921,
#  'hudson': 922,
#  'gaynor': 923,
#  'jones': 924,
#  'houston': 925,
#  'brady': 926,
#  'harlingen': 927,
#  'howard': 928,
#  'cox': 929,
#  'argued': 930,
#  'probably': 931,
#  'unconstitutional': 932,
#  'impair': 933,
#  'complained': 934,
#  'enough': 935,
#  'introduced': 936,
#  'senators': 937,
#  'unanimously': 938,
#  'parkhouse': 939,
#  'dallas': 940,
#  'authorizing': 941,
#  'schools': 942,
#  'deaf': 943,
#  'designed': 944,
#  'special': 945,
#  'schooling': 946,
#  'students': 947,
#  'scholastic': 948,
#  'reduced': 949,
#  'debate': 950,
#  'authorize': 951,
#  'agency': 952,
#  'establish': 953,
#  'county-wide': 954,
#  '300,000': 955,
#  'population': 956,
#  'require': 957,
#  'children': 958,
#  'between': 959,
#  '6': 960,
#  'attend': 961,
#  'permitting': 962,
#  'older': 963,
#  'residential': 964,
#  'here': 965,
#  'budget': 966,
#  'harris': 967,
#  'bexar': 968,
#  'tarrant': 969,
#  'el': 970,
#  'paso': 971,
#  '$451,500': 972,
#  'savings': 973,
#  '$157,460': 974,
#  'yearly': 975,
#  "year's": 976,
#  'capital': 977,
#  'outlay': 978,
#  '$88,000': 979,
#  'absorbed': 980,
#  'tea': 981,
#  'estimated': 982,
#  '182': 983,
#  'scholastics': 984,
#  'saving': 985,
#  'coming': 986,
#  'live': 987,
#  'get': 988,
#  'hear': 989,
#  'horse': 990,
#  'parimutuels': 991,
#  'reps.': 992,
#  'v.': 993,
#  'red': 994,
#  'joe': 995,
#  'ratcliff': 996,
#  'still': 997,
#  'expects': 998,
#  'tell': 999,
#  'folks': 1000,
#  ...}

# %%
index_word = {v: k for k, v in myDic.items()}
index_word
# Out:
# {1: 'the',
#  2: 'fulton',
#  3: 'county',
#  4: 'grand',
#  5: 'jury',
#  6: 'said',
#  7: 'friday',
#  8: 'an',
#  9: 'investigation',
#  10: 'of',
#  11: "atlanta's",
#  12: 'recent',
#  13: 'primary',
#  14: 'election',
#  15: 'produced',
#  16: '``',
#  17: 'no',
#  18: 'evidence',
#  19: "''",
#  20: 'that',
#  21: 'any',
#  22: 'irregularities',
#  23: 'took',
#  24: 'place',
#  25: '.',
#  26: 'further',
#  27: 'in',
#  28: 'term-end',
#  29: 'presentments',
#  30: 'city',
#  31: 'executive',
#  32: 'committee',
#  33: ',',
#  34: 'which',
#  35: 'had',
#  36: 'over-all',
#  37: 'charge',
#  38: 'deserves',
#  39: 'praise',
#  40: 'and',
#  41: 'thanks',
#  42: 'atlanta',
#  43: 'for',
#  44: 'manner',
#  45: 'was',
#  46: 'conducted',
#  47: 'september-october',
#  48: 'term',
#  49: 'been',
#  50: 'charged',
#  51: 'by',
#  52: 'superior',
#  53: 'court',
#  54: 'judge',
#  55: 'durwood',
#  56: 'pye',
#  57: 'to',
#  58: 'investigate',
#  59: 'reports',
#  60: 'possible',
#  61: 'hard-fought',
#  62: 'won',
#  63: 'mayor-nominate',
#  64: 'ivan',
#  65: 'allen',
#  66: 'jr.',
#  67: 'only',
#  68: 'a',
#  69: 'relative',
#  70: 'handful',
#  71: 'such',
#  72: 'received',
#  73: 'considering',
#  74: 'widespread',
#  75: 'interest',
#  76: 'number',
#  77: 'voters',
#  78: 'size',
#  79: 'this',
#  80: 'it',
#  81: 'did',
#  82: 'find',
#  83: 'many',
#  84: "georgia's",
#  85: 'registration',
#  86: 'laws',
#  87: 'are',
#  88: 'outmoded',
#  89: 'or',
#  90: 'inadequate',
#  91: 'often',
#  92: 'ambiguous',
#  93: 'recommended',
#  94: 'legislators',
#  95: 'act',
#  96: 'have',
#  97: 'these',
#  98: 'studied',
#  99: 'revised',
#  100: 'end',
#  101: 'modernizing',
#  102: 'improving',
#  103: 'them',
#  104: 'commented',
#  105: 'on',
#  106: 'other',
#  107: 'topics',
#  108: 'among',
#  109: 'purchasing',
#  110: 'departments',
#  111: 'well',
#  112: 'operated',
#  113: 'follow',
#  114: 'generally',
#  115: 'accepted',
#  116: 'practices',
#  117: 'inure',
#  118: 'best',
#  119: 'both',
#  120: 'governments',
#  121: 'merger',
#  122: 'proposed',
#  123: 'however',
#  124: 'believes',
#  125: 'two',
#  126: 'offices',
#  127: 'should',
#  128: 'be',
#  129: 'combined',
#  130: 'achieve',
#  131: 'greater',
#  132: 'efficiency',
#  133: 'reduce',
#  134: 'cost',
#  135: 'administration',
#  136: 'department',
#  137: 'is',
#  138: 'lacking',
#  139: 'experienced',
#  140: 'clerical',
#  141: 'personnel',
#  142: 'as',
#  143: 'result',
#  144: 'policies',
#  145: 'urged',
#  146: 'take',
#  147: 'steps',
#  148: 'remedy',
#  149: 'problem',
#  150: 'implementation',
#  151: 'automobile',
#  152: 'title',
#  153: 'law',
#  154: 'also',
#  155: 'outgoing',
#  156: 'next',
#  157: 'legislature',
#  158: 'provide',
#  159: 'enabling',
#  160: 'funds',
#  161: 're-set',
#  162: 'effective',
#  163: 'date',
#  164: 'so',
#  165: 'orderly',
#  166: 'may',
#  167: 'effected',
#  168: 'swipe',
#  169: 'at',
#  170: 'state',
#  171: 'welfare',
#  172: "department's",
#  173: 'handling',
#  174: 'federal',
#  175: 'granted',
#  176: 'child',
#  177: 'services',
#  178: 'foster',
#  179: 'homes',
#  180: 'one',
#  181: 'major',
#  182: 'items',
#  183: 'general',
#  184: 'assistance',
#  185: 'program',
#  186: 'but',
#  187: 'has',
#  188: 'seen',
#  189: 'fit',
#  190: 'distribute',
#  191: 'through',
#  192: 'all',
#  193: 'counties',
#  194: 'with',
#  195: 'exception',
#  196: 'receives',
#  197: 'none',
#  198: 'money',
#  199: 'jurors',
#  200: 'they',
#  201: 'realize',
#  202: 'proportionate',
#  203: 'distribution',
#  204: 'might',
#  205: 'disable',
#  206: 'our',
#  207: 'less',
#  208: 'populous',
#  209: 'nevertheless',
#  210: 'we',
#  211: 'feel',
#  212: 'future',
#  213: 'receive',
#  214: 'some',
#  215: 'portion',
#  216: 'available',
#  217: 'failure',
#  218: 'do',
#  219: 'will',
#  220: 'continue',
#  221: 'disproportionate',
#  222: 'burden',
#  223: 'taxpayers',
#  224: "ordinary's",
#  225: 'under',
#  226: 'fire',
#  227: 'its',
#  228: 'appointment',
#  229: 'appraisers',
#  230: 'guardians',
#  231: 'administrators',
#  232: 'awarding',
#  233: 'fees',
#  234: 'compensation',
#  235: 'wards',
#  236: 'protected',
#  237: 'found',
#  238: 'incorporated',
#  239: 'into',
#  240: 'operating',
#  241: 'procedures',
#  242: 'recommendations',
#  243: 'previous',
#  244: 'juries',
#  245: 'bar',
#  246: 'association',
#  247: 'interim',
#  248: 'citizens',
#  249: 'actions',
#  250: 'serve',
#  251: 'protect',
#  252: 'fact',
#  253: 'effect',
#  254: "court's",
#  255: 'from',
#  256: 'undue',
#  257: 'costs',
#  258: 'appointed',
#  259: 'elected',
#  260: 'servants',
#  261: 'unmeritorious',
#  262: 'criticisms',
#  263: 'regarding',
#  264: 'new',
#  265: 'multi-million-dollar',
#  266: 'airport',
#  267: 'when',
#  268: 'management',
#  269: 'takes',
#  270: 'jan.',
#  271: '1',
#  272: 'eliminate',
#  273: 'political',
#  274: 'influences',
#  275: 'not',
#  276: 'elaborate',
#  277: 'added',
#  278: 'there',
#  279: 'periodic',
#  280: 'surveillance',
#  281: 'pricing',
#  282: 'concessionaires',
#  283: 'purpose',
#  284: 'keeping',
#  285: 'prices',
#  286: 'reasonable',
#  287: 'ask',
#  288: 'jail',
#  289: 'deputies',
#  290: 'matters',
#  291: ':',
#  292: '(',
#  293: ')',
#  294: 'four',
#  295: 'additional',
#  296: 'employed',
#  297: 'doctor',
#  298: 'medical',
#  299: 'intern',
#  300: 'extern',
#  301: 'night',
#  302: 'weekend',
#  303: 'duty',
#  304: '2',
#  305: 'work',
#  306: 'officials',
#  307: 'pass',
#  308: 'legislation',
#  309: 'permit',
#  310: 'establishment',
#  311: 'fair',
#  312: 'equitable',
#  313: 'pension',
#  314: 'plan',
#  315: 'employes',
#  316: 'praised',
#  317: 'operation',
#  318: 'police',
#  319: 'tax',
#  320: "commissioner's",
#  321: 'office',
#  322: 'bellwood',
#  323: 'alpharetta',
#  324: 'prison',
#  325: 'farms',
#  326: 'grady',
#  327: 'hospital',
#  328: 'health',
#  329: 'mayor',
#  330: 'william',
#  331: 'b.',
#  332: 'hartsfield',
#  333: 'filed',
#  334: 'suit',
#  335: 'divorce',
#  336: 'his',
#  337: 'wife',
#  338: 'pearl',
#  339: 'williams',
#  340: 'petition',
#  341: 'mental',
#  342: 'cruelty',
#  343: 'couple',
#  344: 'married',
#  345: 'aug.',
#  346: '1913',
#  347: 'son',
#  348: 'berry',
#  349: 'daughter',
#  350: 'mrs.',
#  351: 'j.',
#  352: 'm.',
#  353: 'cheshire',
#  354: 'griffin',
#  355: 'attorneys',
#  356: 'amicable',
#  357: 'property',
#  358: 'settlement',
#  359: 'agreed',
#  360: 'upon',
#  361: 'listed',
#  362: "mayor's",
#  363: 'occupation',
#  364: 'attorney',
#  365: 'age',
#  366: '71',
#  367: "wife's",
#  368: '74',
#  369: 'birth',
#  370: 'opelika',
#  371: 'ala.',
#  372: 'lived',
#  373: 'together',
#  374: 'man',
#  375: 'more',
#  376: 'than',
#  377: 'year',
#  378: 'home',
#  379: '637',
#  380: 'e.',
#  381: 'pelham',
#  382: 'rd.',
#  383: 'aj',
#  384: 'henry',
#  385: 'l.',
#  386: 'bowden',
#  387: 'brief',
#  388: 'interlude',
#  389: 'since',
#  390: '1937',
#  391: 'career',
#  392: 'goes',
#  393: 'back',
#  394: 'council',
#  395: '1923',
#  396: 'present',
#  397: 'expires',
#  398: 'he',
#  399: 'succeeded',
#  400: 'who',
#  401: 'became',
#  402: 'candidate',
#  403: 'sept.',
#  404: '13',
#  405: 'after',
#  406: 'announced',
#  407: 'would',
#  408: 'run',
#  409: 'reelection',
#  410: 'georgia',
#  411: 'republicans',
#  412: 'getting',
#  413: 'strong',
#  414: 'encouragement',
#  415: 'enter',
#  416: '1962',
#  417: "governor's",
#  418: 'race',
#  419: 'top',
#  420: 'official',
#  421: 'wednesday',
#  422: 'robert',
#  423: 'snodgrass',
#  424: 'gop',
#  425: 'chairman',
#  426: 'meeting',
#  427: 'held',
#  428: 'tuesday',
#  429: 'blue',
#  430: 'ridge',
#  431: 'brought',
#  432: 'enthusiastic',
#  433: 'responses',
#  434: 'audience',
#  435: 'party',
#  436: 'james',
#  437: 'w.',
#  438: 'dorsey',
#  439: 'enthusiasm',
#  440: 'picking',
#  441: 'up',
#  442: 'rally',
#  443: '8',
#  444: 'savannah',
#  445: 'newly',
#  446: 'texas',
#  447: 'sen.',
#  448: 'john',
#  449: 'tower',
#  450: 'featured',
#  451: 'speaker',
#  452: 'warned',
#  453: 'entering',
#  454: 'governor',
#  455: 'force',
#  456: 'petitions',
#  457: 'out',
#  458: 'voting',
#  459: 'precincts',
#  460: 'obtain',
#  461: 'signatures',
#  462: 'registered',
#  463: 'despite',
#  464: 'warning',
#  465: 'unanimous',
#  466: 'vote',
#  467: 'according',
#  468: 'attended',
#  469: 'crowd',
#  470: 'asked',
#  471: 'whether',
#  472: 'wanted',
#  473: 'wait',
#  474: 'make',
#  475: 'voted',
#  476: '--',
#  477: 'were',
#  478: 'dissents',
#  479: 'largest',
#  480: 'hurdle',
#  481: 'face',
#  482: 'says',
#  483: 'before',
#  484: 'making',
#  485: 'first',
#  486: 'alternative',
#  487: 'courses',
#  488: 'must',
#  489: 'taken',
#  490: 'five',
#  491: 'per',
#  492: 'cent',
#  493: 'each',
#  494: 'sign',
#  495: 'requesting',
#  496: 'allowed',
#  497: 'names',
#  498: 'candidates',
#  499: 'ballot',
#  500: 'hold',
#  501: 'unit',
#  502: 'system',
#  503: 'opposes',
#  504: 'platform',
#  505: 'sam',
#  506: 'caldwell',
#  507: 'highway',
#  508: 'public',
#  509: 'relations',
#  510: 'director',
#  511: 'resigned',
#  512: 'lt.',
#  513: 'gov.',
#  514: 'garland',
#  515: "byrd's",
#  516: 'campaign',
#  517: "caldwell's",
#  518: 'resignation',
#  519: 'expected',
#  520: 'time',
#  521: 'rob',
#  522: 'ledford',
#  523: 'gainesville',
#  524: 'assistant',
#  525: 'three',
#  526: 'years',
#  527: 'gubernatorial',
#  528: 'starts',
#  529: 'become',
#  530: 'coordinator',
#  531: 'byrd',
#  532: 'wind',
#  533: '1961',
#  534: 'session',
#  535: 'monday',
#  536: 'head',
#  537: 'where',
#  538: 'bond',
#  539: 'approved',
#  540: 'shortly',
#  541: 'adjournment',
#  542: 'afternoon',
#  543: 'senate',
#  544: 'approve',
#  545: 'study',
#  546: 'allotted',
#  547: 'rural',
#  548: 'urban',
#  549: 'areas',
#  550: 'determine',
#  551: 'what',
#  552: 'adjustments',
#  553: 'made',
#  554: 'vandiver',
#  555: 'traditional',
#  556: 'visit',
#  557: 'chambers',
#  558: 'toward',
#  559: 'likely',
#  560: 'mention',
#  561: '$100',
#  562: 'million',
#  563: 'issue',
#  564: 'earlier',
#  565: 'priority',
#  566: 'item',
#  567: 'construction',
#  568: 'bonds',
#  569: 'meanwhile',
#  570: 'learned',
#  571: 'very',
#  572: 'near',
#  573: 'being',
#  574: 'ready',
#  575: '$30',
#  576: 'worth',
#  577: 'reconstruction',
#  578: 'go',
#  579: 'courts',
#  580: 'friendly',
#  581: 'test',
#  582: 'validity',
#  583: 'then',
#  584: 'sales',
#  585: 'begin',
#  586: 'contracts',
#  587: 'let',
#  588: 'repair',
#  589: 'most',
#  590: 'heavily',
#  591: 'traveled',
#  592: 'highways',
#  593: 'source',
#  594: '$3',
#  595: '$4',
#  596: 'roads',
#  597: 'authority',
#  598: 'road',
#  599: 'revolving',
#  600: 'fund',
#  601: 'apparently',
#  602: 'intends',
#  603: 'issued',
#  604: 'every',
#  605: 'old',
#  606: 'ones',
#  607: 'paid',
#  608: 'off',
#  609: 'authorities',
#  610: 'opened',
#  611: '1958',
#  612: 'battle',
#  613: 'against',
#  614: 'issuance',
#  615: '$50',
#  616: 'marvin',
#  617: 'told',
#  618: 'constitution',
#  619: 'consulted',
#  620: 'yet',
#  621: 'about',
#  622: 'plans',
#  623: 'schley',
#  624: 'rep.',
#  625: 'd.',
#  626: 'offer',
#  627: 'resolution',
#  628: 'house',
#  629: 'rescind',
#  630: "body's",
#  631: 'action',
#  632: 'itself',
#  633: '$10',
#  634: 'day',
#  635: 'increase',
#  636: 'expense',
#  637: 'allowances',
#  638: 'sunday',
#  639: 'research',
#  640: 'done',
#  641: 'quickie',
#  642: 'can',
#  643: 'repealed',
#  644: 'outright',
#  645: 'notice',
#  646: 'given',
#  647: 'reconsideration',
#  648: 'sought',
#  649: 'while',
#  650: 'emphasizing',
#  651: 'technical',
#  652: 'details',
#  653: 'fully',
#  654: 'worked',
#  655: 'seek',
#  656: 'set',
#  657: 'aside',
#  658: 'privilege',
#  659: '87-31',
#  660: 'similar',
#  661: 'passed',
#  662: '29-5',
#  663: 'word',
#  664: 'offered',
#  665: 'pointed',
#  666: 'last',
#  667: 'november',
#  668: 'rejected',
#  669: 'constitutional',
#  670: 'amendment',
#  671: 'allow',
#  672: 'pay',
#  673: 'raises',
#  674: 'sessions',
#  675: 'veteran',
#  676: 'jackson',
#  677: 'legislator',
#  678: 'aid',
#  679: 'education',
#  680: 'something',
#  681: 'consistently',
#  682: 'opposed',
#  683: 'past',
#  684: 'mac',
#  685: 'barber',
#  686: 'commerce',
#  687: 'asking',
#  688: 'endorse',
#  689: 'increased',
#  690: 'support',
#  691: 'provided',
#  692: 'expended',
#  693: '13th',
#  694: 'members',
#  695: 'congressional',
#  696: 'delegation',
#  697: 'washington',
#  698: 'like',
#  699: 'see',
#  700: 'congressmen',
#  701: 'specifically',
#  702: 'him',
#  703: 'tossed',
#  704: 'hopper',
#  705: 'formally',
#  706: 'read',
#  707: 'event',
#  708: 'congress',
#  709: 'does',
#  710: 'board',
#  711: 'directed',
#  712: 'give',
#  713: 'teacher',
#  714: 'colquitt',
#  715: 'long',
#  716: 'hot',
#  717: 'controversy',
#  718: 'miller',
#  719: 'school',
#  720: 'superintendent',
#  721: 'policeman',
#  722: 'put',
#  723: 'coolest',
#  724: 'i',
#  725: 'ever',
#  726: 'saw',
#  727: 'harry',
#  728: 'davis',
#  729: 'agriculture',
#  730: 'defeated',
#  731: 'felix',
#  732: 'bush',
#  733: 'principal',
#  734: 'democratic',
#  735: '1,119',
#  736: 'votes',
#  737: "saturday's",
#  738: 'got',
#  739: '402',
#  740: 'ordinary',
#  741: 'carey',
#  742: 'armed',
#  743: 'pistol',
#  744: 'stood',
#  745: 'polls',
#  746: 'insure',
#  747: 'order',
#  748: 'calmest',
#  749: 'tom',
#  750: 'just',
#  751: 'church',
#  752: "didn't",
#  753: 'smell',
#  754: 'drop',
#  755: 'liquor',
#  756: 'bit',
#  757: 'trouble',
#  758: 'leading',
#  759: 'quiet',
#  760: 'marked',
#  761: 'anonymous',
#  762: 'midnight',
#  763: 'phone',
#  764: 'calls',
#  765: 'veiled',
#  766: 'threats',
#  767: 'violence',
#  768: 'former',
#  769: 'george',
#  770: 'p.',
#  771: 'callan',
#  772: 'shot',
#  773: 'himself',
#  774: 'death',
#  775: 'march',
#  776: '18',
#  777: 'days',
#  778: 'post',
#  779: 'dispute',
#  780: 'during',
#  781: 'reportedly',
#  782: 'telephone',
#  783: 'too',
#  784: 'subjected',
#  785: 'soon',
#  786: 'scheduled',
#  787: 'local',
#  788: 'feared',
#  789: 'carry',
#  790: 'gun',
#  791: 'promised',
#  792: 'sheriff',
#  793: 'tabb',
#  794: 'good',
#  795: 'promise',
#  796: 'everything',
#  797: 'went',
#  798: 'real',
#  799: 'smooth',
#  800: "wasn't",
#  801: 'austin',
#  802: 'approval',
#  803: 'price',
#  804: "daniel's",
#  805: 'abandoned',
#  806: 'seemed',
#  807: 'certain',
#  808: 'thursday',
#  809: 'adamant',
#  810: 'protests',
#  811: 'bankers',
#  812: 'daniel',
#  813: 'personally',
#  814: 'led',
#  815: 'fight',
#  816: 'measure',
#  817: 'watered',
#  818: 'down',
#  819: 'considerably',
#  820: 'rejection',
#  821: 'legislatures',
#  822: 'hearing',
#  823: 'revenue',
#  824: 'taxation',
#  825: 'rules',
#  826: 'automatically',
#  827: 'subcommittee',
#  828: 'week',
#  829: 'questions',
#  830: 'taunted',
#  831: 'appearing',
#  832: 'witnesses',
#  833: 'left',
#  834: 'little',
#  835: 'doubt',
#  836: 'recommend',
#  837: 'passage',
#  838: 'termed',
#  839: 'extremely',
#  840: 'conservative',
#  841: 'estimate',
#  842: 'produce',
#  843: '17',
#  844: 'dollars',
#  845: 'help',
#  846: 'erase',
#  847: 'anticipated',
#  848: 'deficit',
#  849: '63',
#  850: 'current',
#  851: 'fiscal',
#  852: '31',
#  853: 'merely',
#  854: 'means',
#  855: 'enforcing',
#  856: 'escheat',
#  857: 'books',
#  858: 'republic',
#  859: 'permits',
#  860: 'over',
#  861: 'bank',
#  862: 'accounts',
#  863: 'stocks',
#  864: 'personal',
#  865: 'persons',
#  866: 'missing',
#  867: 'seven',
#  868: 'bill',
#  869: 'drafted',
#  870: 'banks',
#  871: 'insurance',
#  872: 'firms',
#  873: 'pipeline',
#  874: 'companies',
#  875: 'corporations',
#  876: 'report',
#  877: 'treasurer',
#  878: 'cannot',
#  879: 'enforced',
#  880: 'now',
#  881: 'because',
#  882: 'almost',
#  883: 'impossible',
#  884: 'locate',
#  885: 'declared',
#  886: 'dewey',
#  887: 'lawrence',
#  888: 'tyler',
#  889: 'lawyer',
#  890: 'representing',
#  891: 'sounded',
#  892: 'opposition',
#  893: 'keynote',
#  894: 'violate',
#  895: 'their',
#  896: 'contractual',
#  897: 'obligations',
#  898: 'depositors',
#  899: 'undermine',
#  900: 'confidence',
#  901: 'customers',
#  902: 'if',
#  903: 'you',
#  904: 'destroy',
#  905: 'economy',
#  906: 'circulation',
#  907: 'millions',
#  908: 'charles',
#  909: 'hughes',
#  910: 'sherman',
#  911: 'sponsor',
#  912: 'enact',
#  913: 'amount',
#  914: 'gift',
#  915: "taxpayers'",
#  916: 'pockets',
#  917: 'contention',
#  918: 'denied',
#  919: 'several',
#  920: 'including',
#  921: 'scott',
#  922: 'hudson',
#  923: 'gaynor',
#  924: 'jones',
#  925: 'houston',
#  926: 'brady',
#  927: 'harlingen',
#  928: 'howard',
#  929: 'cox',
#  930: 'argued',
#  931: 'probably',
#  932: 'unconstitutional',
#  933: 'impair',
#  934: 'complained',
#  935: 'enough',
#  936: 'introduced',
#  937: 'senators',
#  938: 'unanimously',
#  939: 'parkhouse',
#  940: 'dallas',
#  941: 'authorizing',
#  942: 'schools',
#  943: 'deaf',
#  944: 'designed',
#  945: 'special',
#  946: 'schooling',
#  947: 'students',
#  948: 'scholastic',
#  949: 'reduced',
#  950: 'debate',
#  951: 'authorize',
#  952: 'agency',
#  953: 'establish',
#  954: 'county-wide',
#  955: '300,000',
#  956: 'population',
#  957: 'require',
#  958: 'children',
#  959: 'between',
#  960: '6',
#  961: 'attend',
#  962: 'permitting',
#  963: 'older',
#  964: 'residential',
#  965: 'here',
#  966: 'budget',
#  967: 'harris',
#  968: 'bexar',
#  969: 'tarrant',
#  970: 'el',
#  971: 'paso',
#  972: '$451,500',
#  973: 'savings',
#  974: '$157,460',
#  975: 'yearly',
#  976: "year's",
#  977: 'capital',
#  978: 'outlay',
#  979: '$88,000',
#  980: 'absorbed',
#  981: 'tea',
#  982: 'estimated',
#  983: '182',
#  984: 'scholastics',
#  985: 'saving',
#  986: 'coming',
#  987: 'live',
#  988: 'get',
#  989: 'hear',
#  990: 'horse',
#  991: 'parimutuels',
#  992: 'reps.',
#  993: 'v.',
#  994: 'red',
#  995: 'joe',
#  996: 'ratcliff',
#  997: 'still',
#  998: 'expects',
#  999: 'tell',
#  1000: 'folks',
#  ...}

# %%
num_words = len(myDic)+1
num_words
# Out:
# 49816

# %% [markdown]
# ## The function "string_to_model_input:"
# * Input: list of words.
# * Output: tuple of two vectors.
#  * create a list of indexes "ids" depending on the dictionary "myDic" the take the first max_sequence_length numbers.
#  * remove the last index from ids list, if the length is less than max_sequence_length then put zeros.
#  * remove the first index from ids list, if the length is less than max_sequence_length then put zeros.

# %%
def string_to_model_input(sentence):
    ids = [myDic[word.lower()] if word.lower() in myDic else 0 for word in sentence][:max_sequence_length]
    l=len(ids)
    X = ids[:-1]+[0]*(max_sequence_length-l+1)
    Y = ids[1:]+[0]*(max_sequence_length-l+1)
    return (np.array(X),np.array(Y))

# %% [markdown]
# ## Calling the function "string_to_model_input" and preparing the data.

# %%
DataSet = [string_to_model_input(sentence)  for sentence in corpus]

# %%
inputData = np.array([tup[0] for tup in DataSet])
outputData = np.array([tup[1] for tup in DataSet])

# %%
inputData
# Out:
# array([[   1,    2,    3, ...,    0,    0,    0],
#        [   1,    5,   26, ...,   30,   10,    0],
#        [   1,   47,   48, ...,   51,   63,    0],
#        ...,
#        [   1, 4077,   10, ...,   27, 1019,    0],
#        [3023,   45,   68, ...,   40,    1,    0],
#        [ 255,  551,  724, ...,    0,    0,    0]])

# %%
outputData
# Out:
# array([[   2,    3,    4, ...,    0,    0,    0],
#        [   5,   26,    6, ...,   10,   42,    0],
#        [  47,   48,    5, ...,   63,   64,    0],
#        ...,
#        [4077,   10,    1, ..., 1019,  536,    0],
#        [  45,   68, 1400, ...,    1, 2947,    0],
#        [ 551,  724,   45, ...,    0,    0,    0]])

# %%
inputData.shape, outputData.shape
# Out:
# ((57340, 32), (57340, 32))

# %% [markdown]
# ## Define the keras model.
# * An Input layer
# * An Embeddings layer.
# * An LSTM layer.
# * A Dense layer with a softmax activation for the output.
#  * The outputs will be a list contians the output of the model and state cells of the LSTM layer.

# %%
visible = Input(shape=max_sequence_length)
hidden1 = Embedding(num_words, 128, input_length=max_sequence_length)(visible)
hidden2 , state_h , state_c = LSTM(32, return_state=True)(hidden1)
output = Dense(max_sequence_length, activation='softmax')(hidden2)
model = Model(inputs=visible, outputs=[output, state_c])
model.compile(loss='CategoricalCrossentropy', optimizer='adam', metrics=['accuracy'])
# summarize layers
print(model.summary())
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 32)]              0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 32, 128)           6376448
# _________________________________________________________________
# lstm_1 (LSTM)                [(None, 32), (None, 32),  20608
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                1056
# =================================================================
# Total params: 6,398,112
# Trainable params: 6,398,112
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# fit the keras model on the dataset
model.fit(inputData, outputData, epochs=5  , batch_size=512)
# Out:
# Epoch 1/5
# 112/112 [==============================] - 15s 131ms/step - loss: 975638.6250 - dense_1_loss: 317193.0312 - lstm_1_loss: 658445.5625 - dense_1_accuracy: 0.1072 - lstm_1_accuracy: 0.0208
# Epoch 2/5
# 112/112 [==============================] - 14s 129ms/step - loss: 977491.5625 - dense_1_loss: 319045.9375 - lstm_1_loss: 658445.4375 - dense_1_accuracy: 0.1072 - lstm_1_accuracy: 0.0208
# Epoch 3/5
# 112/112 [==============================] - 15s 130ms/step - loss: 979132.5000 - dense_1_loss: 320687.1250 - lstm_1_loss: 658445.5625 - dense_1_accuracy: 0.1072 - lstm_1_accuracy: 0.0207
# Epoch 4/5
# 112/112 [==============================] - 15s 130ms/step - loss: 980874.0625 - dense_1_loss: 322428.6562 - lstm_1_loss: 658445.3750 - dense_1_accuracy: 0.1072 - lstm_1_accuracy: 0.0207
# Epoch 5/5
# 112/112 [==============================] - 15s 134ms/step - loss: 982057.8750 - dense_1_loss: 323612.4062 - lstm_1_loss: 658445.3750 - dense_1_accuracy: 0.1072 - lstm_1_accuracy: 0.0206

# %%
def get_cell_state(word_id_vector):
    predictions = model.predict(word_id_vector)
    return predictions[1]

# %%
def predict_next_word(word_sequence):
    ids = string_to_model_input(word_sequence)
    predictions = model.predict(ids[0])
    return index_word[int(max(predictions[0][-1])*num_words)]

# %%
def inputField(): 
    sentence = input('Enter your sentence: ')
    lst = sentence.split(' ')
    return lst

# %% [markdown]
# ## Here you can input a sentence and the model predicts the next word.

# %%
lst = inputField()
print("Your sentence:" , ' '.join(lst))
print("Your sentence with a possible suffix word:" , ' '.join(lst)+' '+ predict_next_word(lst))
# Out:
# Enter your sentence: I am thinking about
# Your sentence: I am thinking about
# WARNING:tensorflow:Model was constructed with shape (None, 32) for input KerasTensor(type_spec=TensorSpec(shape=(None, 32), dtype=tf.float32, name='input_2'), name='input_2', description="created by layer 'input_2'"), but it was called on an input with incompatible shape (32, 1).
# Your sentence with a possible suffix word: I am thinking about facing

# %%
def cosine_similarity(a,b):
    cosine_loss = CosineSimilarity(axis=1)
    return cosine_loss(a,b).numpy()

# %% [markdown]
# ## Here you can input two sentences and you will get the similarity between them.

# %%
def cosineSimField():
    lst1 = inputField()
    lst2 = inputField()
    ids1 = string_to_model_input(lst1)
    ids2 = string_to_model_input(lst1)
    a = get_cell_state(ids1[0])
    b = get_cell_state(ids2[0])
    value = cosine_similarity(a,b)
    print("\nThe first sentence:",' '.join(lst1))
    print("The second sentence:", ' '.join(lst2))
    print("The similarity between the two sentences is:" , value)
cosineSimField()
# Out:
# Enter your sentence: He plays football
# Enter your sentence: I read a book
#
# The first sentence: He plays football
# The second sentence: I read a book
# The similarity between the two sentences is: -0.9999999

# %% [markdown]
# ## Mini search engine.

# %%
f = max_sequence_length
t = AnnoyIndex(f, 'angular')

# %%
for ind,sen in enumerate(corpus):
    lst = []
    for word in sen:
        v = myDic[word.lower()]
        lst.append(v)
    lst = lst[:f]
    L = len(lst)
    lst = lst + [0]*(f-L)
    t.add_item(ind, lst)

# %%
t.build(10) # 10 trees
t.save('test.ann')
t.load('test.ann')
# Out:
# True

# %% [markdown]
# ## Here you can input two sentences and the search engine will give you the 5 nearest neighbors from the index.

# %%
def FiveNearest():
    lst3 = inputField()
    lst3toNum = [myDic[word.lower()] for word in lst3][:f]
    L3 = len(lst3toNum)
    lst3toNum = lst3toNum + [0]*(f-L3)
    fiveInd = t.get_nns_by_vector(lst3toNum, 5, search_k=-1, include_distances=False)
    print(fiveInd)
    for i in fiveInd:
        print('\n' , ' '.join(corpus[i]))
FiveNearest()
# Out:
# Enter your sentence: This is my book
# [14293, 20569, 24172, 49326, 38156]
#
#  there is every indication it will continue .
#
#  It was a worker .
#
#  He got her dozens of them .
#
#  I can see Dan .
#
#  `` I can fix him something later in the afternoon when we get home '' .
